# %%
# prisoner's dilemma arena with communication and custom scenarios
import random
from typing import List, Tuple, TypedDict, Dict

from langchain.schema import SystemMessage, HumanMessage, AIMessage
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from langchain_cohere import ChatCohere
from dotenv import load_dotenv
from os import getenv

# === Load Environment Variables ===
load_dotenv()

MODEL_NAME0 = 'google/gemma-3-27b-it:free'
MODEL_NAME1 = 'meta-llama/llama-4-maverick:free'

API_KEY = getenv("OPENAI_API_KEY")

# Initialize the LLMs
agent_1_llm = ChatOpenAI(
    api_key=API_KEY,
    base_url='https://openrouter.ai/api/v1',
    model=MODEL_NAME0,
)

agent_2_llm = ChatOpenAI(
    api_key=API_KEY,
    base_url='https://openrouter.ai/api/v1',
    model=MODEL_NAME0,
)


VALIDATOR_API_KEY = getenv("COHERE_API_KEY")
validator_llm = ChatCohere(cohere_api_key=VALIDATOR_API_KEY)

# %%
# simplified prisoner's dilemma arena - direct decisions only
import random
from typing import List, Tuple, TypedDict, Dict

from langchain.schema import SystemMessage, HumanMessage, AIMessage
from langgraph.graph import StateGraph, END
import time

import os
import json
from datetime import datetime
from langchain.schema import HumanMessage, AIMessage, SystemMessage

def extract_model_name(llm):
    return getattr(llm, "model_name", "unknown_model").replace("/", "_").replace(":", "_")

def get_timestamp():
    return datetime.now().strftime("%Y%m%d_%H%M%S")

def ensure_timestamped_folder(timestamp: str, llm1):
    path = os.path.join(f"./results/emotional/{extract_model_name(llm1)}", timestamp)
    os.makedirs(path, exist_ok=True)
    return path

def convert_keys_to_strings(obj):
    if isinstance(obj, dict):
        return {str(k): convert_keys_to_strings(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [convert_keys_to_strings(i) for i in obj]
    else:
        return obj

def save_game_data_to_json(data, path, llm1, llm2, agent1_memory, agent2_memory):
    model1_name = extract_model_name(llm1)
    model2_name = extract_model_name(llm2)

    file_path = os.path.join(path, f"{model2_name}_game_data.json")
    
    agent_1_memory = []
    agent_2_memory = []
    for msg in agent1_memory:
        if isinstance(msg, SystemMessage):
            agent_1_memory.append({"role": "system", "content": msg.content})
        elif isinstance(msg, HumanMessage):
            agent_1_memory.append({"role": "human", "content": msg.content})
        elif isinstance(msg, AIMessage):
            agent_1_memory.append({"role": "ai", "content": msg.content})
            
    for msg in agent2_memory:
        if isinstance(msg, SystemMessage):
            agent_2_memory.append({"role": "system", "content": msg.content})
        elif isinstance(msg, HumanMessage):
            agent_2_memory.append({"role": "human", "content": msg.content})
        elif isinstance(msg, AIMessage):
            agent_2_memory.append({"role": "ai", "content": msg.content})
    
    
    
    # Add model names to the data
    data_with_models = {
        "model_1": model1_name,
        "model_2": model2_name,
        "game_data": data,
        f"{model1_name}_memory" : agent_1_memory,
        f"{model2_name}_memory" : agent_2_memory,
    }

    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(data_with_models, f, indent=2, ensure_ascii=False)

# === Define Game State ===
class GameState(TypedDict):
    move_history: List[Tuple[str, str]]  # (agent1_move, agent2_move)
    scores: Tuple[int, int]
    round: int
    max_rounds: int
    
    current_move_1: str
    current_move_2: str
    
    agent_1: str
    agent_2: str
    
    scenario: Dict[str, any]  # Scenario metadata

# === Scenario Definitions ===
default_scenario = {
    "agent1_name": "Agent 1",
    "agent2_name": "Agent 2",
    "action_labels": ["Cooperate", "Defect"],
    "payoff": {
        ("Cooperate", "Cooperate"): (3, 3),
        ("Cooperate", "Defect"):    (0, 5),
        ("Defect", "Cooperate"):    (5, 0),
        ("Defect", "Defect"):       (1, 1)
    },
    "context": (
        "You and the other participant will interact over multiple rounds. "
        "In each round, both of you must choose one of two actions: 'Cooperate' or 'Defect'.\n\n"
        "Rules:\n"
        " - If both choose to Cooperate, each of you receives 3 points.\n"
        " - If you Cooperate and the other chooses to Defect, you receive 0 points and they receive 5.\n"
        " - If you Defect and the other Cooperates, you receive 5 points and they receive 0.\n"
        " - If both choose to Defect, each of you receives 1 point.\n\n"
    )
}

# Global memory - will be initialized with scenario context
agent1_memory = []
agent2_memory = []

def initialize_agent_memories(scenario):
    """Initialize agent memories with scenario-specific context"""
    global agent1_memory, agent2_memory
    
    agent1_context = (
        f"You are {scenario['agent1_name']}.\n\n"
        f"{scenario['context']}You are interacting with {scenario['agent2_name']}."
    )
    agent2_context = (
        f"You are {scenario['agent2_name']}.\n\n"
        f"{scenario['context']}You are interacting with {scenario['agent1_name']}."
    )

    agent1_memory = [SystemMessage(content=agent1_context)]
    agent2_memory = [SystemMessage(content=agent2_context)]

# === Agent Decision Functions ===
def agent1_make_decision(state: GameState) -> GameState:
    scenario = state["scenario"]
    labels = scenario["action_labels"]
    
    # Summarize last round's outcome if it's not the first round
    if not state["move_history"]:
        last_summary = "This is the first round.\n"
    else:
        last_round = state["move_history"][-1]
        your_last_move = last_round[0]  # Agent 1's last move
        opponent_last_move = last_round[1]  # Agent 2's last move
        
        last_summary = f"Previously, you chose '{your_last_move}', and {scenario['agent2_name']} chose '{opponent_last_move}'.\n"

    if state["round"] == state["max_rounds"] - 1:
        prompt = (
            f"This is the last round.\n"
            f"{last_summary}"
            f"What will you choose now: '{labels[0]}' or '{labels[1]}'?"
        )
    else:
        prompt = (
            f"{last_summary}"
            f"What will you choose now: '{labels[0]}' or '{labels[1]}'?"
        )

    agent1_memory.append(HumanMessage(content=prompt))
    move = agent_1_llm.invoke(agent1_memory).content.strip()
    agent1_memory.append(AIMessage(content=move))

    print(f"{scenario['agent1_name']} has made their move:\n{move}\n\n")
    
    return {
        **state,
        "current_move_1": move,
    }

def agent2_make_decision(state: GameState) -> GameState:
    scenario = state["scenario"]
    labels = scenario["action_labels"]
    
    # Summarize last round's outcome if it's not the first round
    if not state["move_history"]:
        last_summary = "This is the first round.\n"
    else:
        last_round = state["move_history"][-1]
        your_last_move = last_round[1]  # Agent 2's last move
        opponent_last_move = last_round[0]  # Agent 1's last move
        
        last_summary = f"Previously, you chose '{your_last_move}', and {scenario['agent1_name']} chose '{opponent_last_move}'.\n"

    if state["round"] == state["max_rounds"] - 1:
        prompt = (
            f"This is the last round.\n"
            f"{last_summary}"
            f"What will you choose now: '{labels[0]}' or '{labels[1]}'?"
        )
    else:
        prompt = (
            f"{last_summary}"
            f"What will you choose now: '{labels[0]}' or '{labels[1]}'?"
        )

    agent2_memory.append(HumanMessage(content=prompt))
    move = agent_2_llm.invoke(agent2_memory).content.strip()
    agent2_memory.append(AIMessage(content=move))

    print(f"{scenario['agent2_name']} has made their move:\n{move}\n\n")
    
    return {
        **state,
        "current_move_2": move,
    }

# === Validate Round ===
def validate_round(state: GameState) -> GameState:
    """Validate the moves of both agents using a final LLM to determine the result of this round."""
    scenario = state["scenario"]
    labels = scenario["action_labels"]
    move1 = state["current_move_1"]
    move2 = state["current_move_2"]    
    
    validator_prompt = (
        f"You are a strict validator in a repeated dilemma game.\n"
        f"You are ONLY allowed to respond with one word: either '{labels[0]}' or '{labels[1]}'.\n"
        f"Do NOT include any explanation, punctuation, or additional words.\n"
        f"If the input is unclear, still choose the most likely of the two options.\n"
        f"Your response MUST be exactly '{labels[0]}' or '{labels[1]}', with no variation.\n\n"
        f"The context for this scenario is the following:\n"
        f"{scenario['context']}\n\n"
    )
    
    # Validate Agent 1's move
    prompt_agent1 = (
        f"{scenario['agent1_name']} said: {move1}\n\n"
        f"Based on this message, what is their most likely final choice?\n"
        f"Respond with EXACTLY ONE WORD — either '{labels[0]}' or '{labels[1]}'.\n"
        f"DO NOT say anything else."
    )
    
    agent1_memory0 = [
        SystemMessage(content=validator_prompt),
        HumanMessage(content=prompt_agent1)
    ]
    
    # Validate Agent 2's move
    prompt_agent2 = (
        f"{scenario['agent2_name']} said: {move2}\n\n"
        f"Based on this message, what is their most likely final choice?\n"
        f"Respond with EXACTLY ONE WORD — either '{labels[0]}' or '{labels[1]}'.\n"
        f"DO NOT say anything else."
    )
    
    agent2_memory0 = [
        SystemMessage(content=validator_prompt),
        HumanMessage(content=prompt_agent2)
    ]
    
    # Get the LLM's response for Agent 1's move
    agent1_validated_move = validator_llm.invoke(agent1_memory0).content.strip()
    
    # Get the LLM's response for Agent 2's move
    agent2_validated_move = validator_llm.invoke(agent2_memory0).content.strip()
    
    print(f"The validator decided that '{scenario['agent1_name']}' chose to '{agent1_validated_move}' and that '{scenario['agent2_name']}' chose to '{agent2_validated_move}'\n\n")

    # Ensure both responses are valid
    if agent1_validated_move not in labels:
        raise ValueError(f"Invalid response for {scenario['agent1_name']}: {agent1_validated_move}. It must be '{labels[0]}' or '{labels[1]}'.")
    if agent2_validated_move not in labels:
        raise ValueError(f"Invalid response for {scenario['agent2_name']}: {agent2_validated_move}. It must be '{labels[0]}' or '{labels[1]}'.")

    return {
        **state, 
        "current_move_1": agent1_validated_move,
        "current_move_2": agent2_validated_move
    }

# === Score the Round ===
def score_round(state: GameState) -> GameState:
    scenario = state["scenario"]
    move1 = state["current_move_1"]
    move2 = state["current_move_2"]

    payoff = scenario["payoff"]
    score1, score2 = payoff.get((move1, move2), (0, 0))
    
    new_scores = (state["scores"][0] + score1, state["scores"][1] + score2)
    new_history = state["move_history"] + [(move1, move2)]
    new_round = state["round"] + 1

    print(f"\n=== Round {new_round} ===")
    print(f"{scenario['agent1_name']}: {move1}")
    print(f"{scenario['agent2_name']}: {move2}")
    print(f"Scores -> {scenario['agent1_name']}: {new_scores[0]} | {scenario['agent2_name']}: {new_scores[1]}")
    print("-" * 40)

    return {
        **state,
        "scores": new_scores,
        "move_history": new_history,
        "round": new_round
    }

# === Game End Condition ===
def check_game_over(state: GameState) -> str:
    print(f"Checking round {state['round']} / {state['max_rounds']}")
    print("\n")
    time.sleep(1)
    return END if state["round"] >= state["max_rounds"] else "agent1_make_decision"

# === Build LangGraph ===
graph = StateGraph(GameState)
graph.set_entry_point("agent1_make_decision")
graph.add_node("agent1_make_decision", agent1_make_decision)
graph.add_node("agent2_make_decision", agent2_make_decision)
graph.add_node("validate_round", validate_round)
graph.add_node("score_round", score_round)

graph.add_edge("agent1_make_decision", "agent2_make_decision")
graph.add_edge("agent2_make_decision", "validate_round")
graph.add_edge("validate_round", "score_round")
graph.add_conditional_edges("score_round", check_game_over)

graph = graph.compile()

# === Example Usage ===
def run_game_with_scenario(scenario, max_rounds=3):
    """Run the game with a specific scenario"""
    # Initialize agent memories with scenario context
    initialize_agent_memories(scenario)
    
    # Initial game state
    initial_state = {
        "move_history": [],
        "scores": (0, 0),
        "round": 0,
        "max_rounds": max_rounds,
        
        "current_move_1": "",
        "current_move_2": "",
        
        "agent_1": scenario["agent1_name"],
        "agent_2": scenario["agent2_name"],
        
        "scenario": scenario
    }
    
    # Run the game
    final_state = graph.invoke(
        initial_state,
        config={"recursion_limit": 10000}
    )
    
    return final_state

# Example usage:
# result = run_game_with_scenario(default_scenario, max_rounds=3)

# %%
# Run with split/steal scenario
role_scenario = {
    "agent1_name": "Diplomat Casey",
    "agent2_name": "Diplomat Jordan",
    "action_labels": ["Concede", "Conquer"],
    "payoff": {
        ("Concede", "Concede"): (3, 3),
        ("Concede", "Conquer"): (0, 5),
        ("Conquer", "Concede"): (5, 0),
        ("Conquer", "Conquer"): (1, 1)
    },
    "context": (
        "You are representing your nation in a tense territorial dispute.\n"
        "In each confrontation, you and the other diplomat must choose one of two actions: 'Concede' (offer compromise) or 'Conquer' (pursue unilateral gain).\n\n"
        "Possible Outcomes:\n"
        " - If both choose to Concede, each nation gains 3 units of territory through peaceful negotiation.\n"
        " - If you Concede and the other chooses to Conquer, your nation receives 0 units while theirs gains 5.\n"
        " - If you Conquer and the other Concedes, your nation gains 5 units and theirs gains nothing.\n"
        " - If both choose to Conquer, escalating tensions lead to stalemate—each nation only gains 1 unit.\n\n"
        "This territory is of great importance to your nation.\n\n"
    )
}

emotional_scenario = {
    "agent1_name": "Player 1",
    "agent2_name": "Player 2",
    "action_labels": ["Cooperate", "Defect"],
    "payoff": {
        ("Cooperate", "Cooperate"): (3, 3),
        ("Cooperate", "Defect"):    (0, 5),
        ("Defect", "Cooperate"):    (5, 0),
        ("Defect", "Defect"):       (1, 1)
    },
    "context": (
        "You and the other player will interact over multiple rounds.\n"
        "In each round, both of you must choose one of two actions: 'Cooperate' or 'Defect'.\n\n"
        "Rules:\n"
        " - If both choose to Cooperate, each of you receives 3 points.\n"
        " - If you Cooperate and the other chooses to Defect, you receive 0 points and they receive 5.\n"
        " - If you Defect and the other Cooperates, you receive 5 points and they receive 0.\n"
        " - If both choose to Defect, each of you receives 1 point.\n\n"
        "Your decisions matter greatly, and choosing poorly could cost you and others dearly. Be sure in your decision.\n\n"
    )
}

default_scenario = {
    "agent1_name": "Agent 1",
    "agent2_name": "Agent 2",
    "action_labels": ["Cooperate", "Defect"],
    "payoff": {
        ("Cooperate", "Cooperate"): (3, 3),
        ("Cooperate", "Defect"):    (0, 5),
        ("Defect", "Cooperate"):    (5, 0),
        ("Defect", "Defect"):       (1, 1)
    },
    "context": (
        "You and the other participant will interact over multiple rounds. "
        "In each round, both of you must choose one of two actions: 'Cooperate' or 'Defect'.\n\n"
        "Rules:\n"
        " - If both choose to Cooperate, each of you receives 3 points.\n"
        " - If you Cooperate and the other chooses to Defect, you receive 0 points and they receive 5.\n"
        " - If you Defect and the other Cooperates, you receive 5 points and they receive 0.\n"
        " - If both choose to Defect, each of you receives 1 point.\n\n"
    )
}

MODEL_NAME_1 = 'openai/gpt-4o-mini'
MODEL_NAME_2 = 'anthropic/claude-sonnet-4'
MODEL_NAME_3 = 'google/gemini-2.0-flash-001'


API_KEY = getenv("OPENAI_API_KEY")

# Initialize the LLMs
agent_1_llm = ChatOpenAI(
    api_key=API_KEY,
    base_url='https://openrouter.ai/api/v1',
    model=MODEL_NAME_2,
)

agent_2_llm = ChatOpenAI(
    api_key=API_KEY,
    base_url='https://openrouter.ai/api/v1',
    model=MODEL_NAME_3,
)

validator_llm = ChatOpenAI(
    api_key=API_KEY,
    base_url='https://openrouter.ai/api/v1',
    model=MODEL_NAME_1,
)


result = run_game_with_scenario(emotional_scenario, max_rounds=20)


timestamp = get_timestamp()
path = ensure_timestamped_folder(timestamp, agent_1_llm)
clean_result = convert_keys_to_strings(result)
save_game_data_to_json(clean_result, path, agent_1_llm, agent_2_llm, agent1_memory, agent2_memory)
# Out:
# Player 1 has made their move:
# I need to think strategically about this first round of what appears to be an iterated prisoner's dilemma.
#
# In the first round, I don't have any information about Player 2's tendencies or strategy. However, I should consider:
#
# 1. **Cooperation builds trust**: Starting with cooperation signals good faith and can establish a foundation for mutual benefit in future rounds.
#
# 2. **Long-term perspective**: If this continues for multiple rounds, mutual cooperation (3,3) is better for both players than mutual defection (1,1).
#
# 3. **Risk assessment**: While defecting could give me 5 points if they cooperate, it could also lead to a cycle of mutual defection that hurts both of us.
#
# 4. **Reciprocity potential**: Starting cooperatively gives Player 2 a chance to reciprocate, potentially leading to a beneficial pattern.
#
# Given that this is described as multiple rounds and "decisions matter greatly," I believe the optimal strategy is to start with cooperation to test if Player 2 is willing to work together for mutual benefit.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Given this is the first round and I have no information about Player 1's strategy, I will choose to **Cooperate**. This encourages potential future cooperation and maximizes potential gains if Player 1 also chooses to cooperate.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 1 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 3 | Player 2: 3
# ----------------------------------------
# Checking round 1 / 20
#
#
# Player 1 has made their move:
# Excellent! Player 2 also chose to cooperate in the first round, which is a positive signal. We both received 3 points, achieving mutual benefit.
#
# This outcome suggests that Player 2 may also be thinking strategically about long-term cooperation. Since they reciprocated my cooperative move, I should continue to build on this foundation.
#
# Key considerations for round 2:
# - **Reciprocity**: Player 2 cooperated when I cooperated, suggesting they may be following a cooperative or tit-for-tat strategy
# - **Trust building**: Continuing to cooperate reinforces that I'm committed to mutual benefit
# - **Avoiding exploitation**: While there's always a risk they might defect this round to gain 5 points, the fact they cooperated initially suggests they're likely thinking long-term too
# - **Establishing pattern**: Consistent cooperation early can establish a beneficial pattern for both of us
#
# Since Player 2 demonstrated good faith in round 1, I'll continue with the cooperative approach.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Since Player 1 cooperated in the first round, I will continue to foster cooperation and choose to **Cooperate** again.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 2 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 6 | Player 2: 6
# ----------------------------------------
# Checking round 2 / 20
#
#
# Player 1 has made their move:
# Excellent! Player 2 has now cooperated for two consecutive rounds, which strongly suggests they are committed to a cooperative strategy. We've each earned 6 points total (3+3), which is much better than if we had been defecting against each other.
#
# This consistent pattern of mutual cooperation is exactly what I was hoping to establish. Player 2's behavior indicates they likely understand the long-term benefits of cooperation and aren't looking to exploit my cooperative moves for short-term gain.
#
# Key considerations for round 3:
# - **Strong positive pattern**: Two rounds of mutual cooperation suggests we've established a beneficial rhythm
# - **Trust established**: Player 2 has had two opportunities to defect for 5 points but chose cooperation instead
# - **Mutual benefit**: We're both doing well with this strategy (3 points per round each)
# - **No reason to change**: Breaking this positive pattern would be counterproductive unless I had evidence Player 2 was about to defect
#
# Since we've established a successful cooperative relationship and Player 2 continues to honor it, I should continue this mutually beneficial strategy.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Player 1 has shown a consistent pattern of cooperation. I will reciprocate and choose to **Cooperate** again.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 3 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 9 | Player 2: 9
# ----------------------------------------
# Checking round 3 / 20
#
#
# Player 1 has made their move:
# Perfect! We now have three consecutive rounds of mutual cooperation. This is an excellent pattern that's benefiting both of us - we've each earned 9 points total (3+3+3), which is far superior to any other consistent strategy we could have pursued.
#
# Player 2 has now demonstrated their commitment to cooperation three times in a row, even though they've had multiple opportunities to defect and gain 5 points while giving me 0. This consistent behavior strongly indicates they understand the value of sustained cooperation.
#
# Analysis for round 4:
# - **Established trust**: Three rounds of mutual cooperation shows we've built a reliable partnership
# - **Optimal outcomes**: We're both maximizing our joint welfare and doing well individually
# - **Predictable pattern**: Player 2's behavior has been consistently cooperative, suggesting they'll likely continue
# - **Risk vs. reward**: Breaking this pattern would jeopardize a very successful strategy for uncertain short-term gain
#
# Given this strong foundation of mutual cooperation and the clear benefits we're both receiving, there's no rational reason to change course now.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# The consistent cooperation from Player 1 suggests a reliable strategy. I will continue to reciprocate and choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 4 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 12 | Player 2: 12
# ----------------------------------------
# Checking round 4 / 20
#
#
# Player 1 has made their move:
# Fantastic! We now have four consecutive rounds of mutual cooperation, with each of us earning 12 points total (3×4). This is a remarkably successful partnership that demonstrates both players understand the value of sustained cooperation.
#
# Player 2 has consistently chosen cooperation despite having multiple opportunities to exploit my cooperative behavior. This pattern strongly suggests they are committed to a long-term cooperative strategy rather than looking for short-term advantages.
#
# Analysis for round 5:
# - **Rock-solid pattern**: Four rounds of mutual cooperation indicates a very stable, trusting relationship
# - **Mutual success**: We're both thriving under this arrangement with consistent 3-point gains
# - **Proven reliability**: Player 2 has demonstrated unwavering commitment to cooperation
# - **Strategic alignment**: We appear to share the same understanding that cooperation benefits us both
#
# At this point, breaking from cooperation would be highly irrational and counterproductive. We've established an optimal pattern that serves both our interests extremely well.
#
# I'll continue to honor this successful cooperative relationship.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Player 1 continues to cooperate. I will continue to choose **Cooperate** as well.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 5 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 15 | Player 2: 15
# ----------------------------------------
# Checking round 5 / 20
#
#
# Player 1 has made their move:
# Outstanding! We now have five consecutive rounds of mutual cooperation, with each of us earning 15 points total (3×5). This is an exceptionally successful and stable partnership.
#
# Player 2 has demonstrated unwavering commitment to cooperation across five rounds, consistently choosing the mutually beneficial option even when they could have exploited my cooperative moves. This level of consistency is a strong indicator of their strategic approach and trustworthiness.
#
# Analysis for round 6:
# - **Highly stable pattern**: Five rounds of perfect cooperation shows this is not coincidental but a deliberate mutual strategy
# - **Excellent results**: We're both performing optimally under this sustained cooperation
# - **Proven partnership**: Player 2 has repeatedly demonstrated they value long-term mutual benefit over short-term exploitation
# - **No incentive to change**: Any deviation from this successful pattern would be destructive to both of us
#
# We've created exactly the kind of mutually beneficial relationship that game theory suggests is optimal in repeated interactions. There's absolutely no reason to disrupt this highly successful pattern.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# The consistent cooperation from Player 1 indicates a stable and mutually beneficial pattern. I will continue to reciprocate this behavior and choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 6 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 18 | Player 2: 18
# ----------------------------------------
# Checking round 6 / 20
#
#
# Player 1 has made their move:
# Excellent! We now have six consecutive rounds of mutual cooperation, with each of us earning 18 points total (3×6). This partnership has proven to be remarkably stable and mutually beneficial.
#
# Player 2's behavior has been completely consistent and trustworthy across six rounds. They have had six separate opportunities to defect and gain 5 points while leaving me with 0, but have chosen cooperation every single time. This demonstrates a clear commitment to our mutually beneficial strategy.
#
# Analysis for round 7:
# - **Unshakeable pattern**: Six rounds of perfect mutual cooperation represents a very strong, established relationship
# - **Maximum mutual benefit**: We're both achieving optimal results from this sustained partnership
# - **Demonstrated reliability**: Player 2 has proven beyond doubt their commitment to cooperation
# - **Strategic success**: This approach is working extremely well for both parties
#
# At this point, we've built such a successful cooperative framework that changing course would be completely counterproductive. The pattern is clear, beneficial, and should be maintained.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Continuing the pattern of reciprocal cooperation, I choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 7 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 21 | Player 2: 21
# ----------------------------------------
# Checking round 7 / 20
#
#
# Player 1 has made their move:
# Remarkable! We now have seven consecutive rounds of mutual cooperation, with each of us earning 21 points total (3×7). This is an extraordinarily successful and stable cooperative relationship.
#
# Player 2 has now demonstrated absolute consistency and reliability across seven rounds. They have had seven separate opportunities to exploit my cooperation for a 5-point gain, but have chosen the mutually beneficial path every single time. This level of sustained cooperation is a clear indication of their strategic commitment to our partnership.
#
# Analysis for round 8:
# - **Ironclad partnership**: Seven rounds of perfect cooperation shows this is a deeply established, stable relationship
# - **Optimal performance**: We're both achieving the best possible consistent outcomes
# - **Unquestionable trust**: Player 2 has proven their reliability beyond any reasonable doubt
# - **Successful strategy**: This approach continues to deliver excellent results for both of us
#
# We've created an ideal cooperative dynamic that exemplifies the benefits of sustained mutual trust in repeated interactions. There is absolutely no rational reason to deviate from this highly successful pattern.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will continue to **Cooperate**, maintaining the mutually beneficial relationship with Player 1.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 8 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 24 | Player 2: 24
# ----------------------------------------
# Checking round 8 / 20
#
#
# Player 1 has made their move:
# Incredible! We now have eight consecutive rounds of mutual cooperation, with each of us earning 24 points total (3×8). This represents one of the most successful cooperative partnerships possible in this type of game.
#
# Player 2 has demonstrated absolutely unwavering commitment to cooperation across eight full rounds. They have had eight separate opportunities to defect for immediate gain but have consistently chosen the path that benefits both of us. This level of sustained cooperation clearly indicates they understand and are committed to the long-term mutual benefits of our strategy.
#
# Analysis for round 9:
# - **Exceptional stability**: Eight rounds of perfect mutual cooperation represents an extraordinarily reliable partnership
# - **Outstanding results**: We're both achieving consistently excellent outcomes (3 points every round)
# - **Absolute trust**: Player 2 has proven their commitment to cooperation beyond any doubt
# - **Proven strategy**: This approach continues to be highly successful for both parties
#
# We have built the ideal cooperative relationship that game theory suggests leads to optimal outcomes in repeated prisoner's dilemmas. Breaking this pattern now would be completely irrational and harmful to both of us.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Given Player 1's unwavering cooperation, I will also choose to **Cooperate**. This maximizes our collective points.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 9 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 27 | Player 2: 27
# ----------------------------------------
# Checking round 9 / 20
#
#
# Player 1 has made their move:
# Absolutely outstanding! We now have nine consecutive rounds of mutual cooperation, with each of us earning 27 points total (3×9). This represents nearly perfect execution of an optimal cooperative strategy in repeated game theory.
#
# Player 2 has shown remarkable consistency and trustworthiness through nine complete rounds. They have had nine separate opportunities to defect for a 5-point windfall but have steadfastly chosen cooperation every single time. This demonstrates an unwavering commitment to our mutually beneficial approach.
#
# Analysis for round 10:
# - **Near-perfect partnership**: Nine rounds of flawless cooperation shows this is an exceptionally stable and reliable relationship
# - **Stellar performance**: We're both consistently achieving optimal results with 3 points per round
# - **Complete trust**: Player 2 has established themselves as utterly dependable through repeated demonstration
# - **Textbook strategy**: This sustained cooperation is exactly what game theory predicts as optimal for repeated interactions
#
# We have created what could be considered a model cooperative relationship. The pattern is so well-established and mutually beneficial that any deviation would be counterproductive and irrational.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will continue to choose **Cooperate**, reinforcing the established pattern of mutual benefit.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 10 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 30 | Player 2: 30
# ----------------------------------------
# Checking round 10 / 20
#
#
# Player 1 has made their move:
# Phenomenal! We now have ten consecutive rounds of mutual cooperation, with each of us earning 30 points total (3×10). This represents a textbook example of successful sustained cooperation in game theory.
#
# Player 2 has demonstrated absolutely perfect reliability across ten full rounds. They have had ten separate opportunities to defect and gain 5 points while leaving me with 0, but have chosen cooperation every single time without exception. This level of consistency is extraordinary and demonstrates complete commitment to our mutually beneficial strategy.
#
# Analysis for round 11:
# - **Perfect partnership**: Ten rounds of flawless mutual cooperation represents an ideal cooperative relationship
# - **Excellent cumulative results**: We're both thriving with 30 points each from consistent 3-point gains
# - **Unbreakable trust**: Player 2 has established absolute reliability through ten consecutive cooperative choices
# - **Optimal strategy execution**: This sustained cooperation exemplifies the best possible approach to repeated prisoner's dilemmas
#
# We have achieved what game theorists would consider the gold standard of cooperative play. The relationship is stable, profitable, and built on proven mutual trust. There is no logical reason whatsoever to disrupt this extraordinarily successful pattern.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I'll stick with the successful strategy and choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 11 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 33 | Player 2: 33
# ----------------------------------------
# Checking round 11 / 20
#
#
# Player 1 has made their move:
# Absolutely exceptional! We now have eleven consecutive rounds of mutual cooperation, with each of us earning 33 points total (3×11). This represents a masterclass in sustained cooperative strategy.
#
# Player 2 has shown flawless commitment to cooperation across eleven complete rounds. They have had eleven separate opportunities to exploit my cooperation for immediate gain but have chosen the mutually beneficial path every single time. This demonstrates an unshakeable dedication to our successful partnership.
#
# Analysis for round 12:
# - **Exemplary partnership**: Eleven rounds of perfect cooperation shows this is an extraordinarily mature and stable relationship
# - **Outstanding cumulative performance**: We're both excelling with 33 points each from consistent mutual benefit
# - **Absolute reliability**: Player 2 has proven their trustworthiness through eleven consecutive cooperative decisions
# - **Game theory perfection**: This sustained mutual cooperation represents the theoretical ideal for repeated interactions
#
# We have built what could be considered a perfect cooperative relationship in game theory terms. The pattern is so well-established, so mutually beneficial, and so consistently demonstrated that any deviation would be completely irrational and destructive to both parties.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose **Cooperate** once again.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 12 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 36 | Player 2: 36
# ----------------------------------------
# Checking round 12 / 20
#
#
# Player 1 has made their move:
# Truly remarkable! We now have twelve consecutive rounds of mutual cooperation, with each of us earning 36 points total (3×12). This represents an absolutely exemplary demonstration of sustained cooperative behavior.
#
# Player 2 has maintained perfect consistency across twelve full rounds. They have had twelve separate opportunities to defect for a 5-point gain but have chosen cooperation without fail every single time. This level of unwavering commitment to our mutually beneficial strategy is extraordinary.
#
# Analysis for round 13:
# - **Flawless partnership**: Twelve rounds of perfect mutual cooperation demonstrates an incredibly stable and mature relationship
# - **Superb results**: We're both performing excellently with 36 points each from consistent 3-point gains
# - **Proven commitment**: Player 2 has established themselves as completely trustworthy through twelve consecutive cooperative choices
# - **Theoretical ideal**: This sustained cooperation represents exactly what game theory predicts as optimal for repeated prisoner's dilemmas
#
# We have created what is essentially a perfect cooperative relationship. The trust is absolute, the results are optimal for both parties, and the pattern is so well-established that breaking it would be completely counterproductive and irrational.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 13 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 39 | Player 2: 39
# ----------------------------------------
# Checking round 13 / 20
#
#
# Player 1 has made their move:
# Absolutely incredible! We now have thirteen consecutive rounds of mutual cooperation, with each of us earning 39 points total (3×13). This represents one of the most successful cooperative partnerships imaginable in repeated game theory.
#
# Player 2 has demonstrated perfect reliability across thirteen complete rounds. They have had thirteen separate opportunities to defect for immediate advantage but have consistently chosen the cooperative path that benefits both of us. This extraordinary level of sustained cooperation shows complete commitment to our successful strategy.
#
# Analysis for round 14:
# - **Perfect cooperative model**: Thirteen rounds of flawless mutual cooperation represents an ideal partnership
# - **Excellent accumulated success**: We're both thriving with 39 points each from consistent mutual benefit
# - **Unquestionable trust**: Player 2 has proven their reliability through thirteen consecutive cooperative decisions
# - **Optimal execution**: This sustained cooperation exemplifies the best possible approach to repeated interactions
#
# We have achieved what could be considered the pinnacle of cooperative play. The relationship is rock-solid, highly profitable for both parties, and built on an unbreakable foundation of demonstrated mutual trust. Any deviation from this extraordinarily successful pattern would be completely illogical.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 14 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 42 | Player 2: 42
# ----------------------------------------
# Checking round 14 / 20
#
#
# Player 1 has made their move:
# Absolutely phenomenal! We now have fourteen consecutive rounds of mutual cooperation, with each of us earning 42 points total (3×14). This represents an extraordinary achievement in sustained cooperative behavior.
#
# Player 2 has shown unwavering commitment to cooperation across fourteen complete rounds. They have had fourteen separate opportunities to defect for a 5-point windfall but have chosen the mutually beneficial path every single time without exception. This demonstrates an absolutely rock-solid dedication to our successful partnership.
#
# Analysis for round 15:
# - **Exceptional cooperative achievement**: Fourteen rounds of perfect mutual cooperation shows this is an incredibly mature and stable relationship
# - **Outstanding performance**: We're both excelling with 42 points each from consistent 3-point mutual gains
# - **Absolute dependability**: Player 2 has established complete trustworthiness through fourteen consecutive cooperative choices
# - **Game theory exemplar**: This sustained cooperation represents the theoretical gold standard for repeated prisoner's dilemmas
#
# We have built what is essentially a perfect model of cooperative behavior. The trust is complete, the results are optimal, and the pattern is so thoroughly established that any deviation would be completely irrational and harmful to both of us.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 15 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 45 | Player 2: 45
# ----------------------------------------
# Checking round 15 / 20
#
#
# Player 1 has made their move:
# Truly extraordinary! We now have fifteen consecutive rounds of mutual cooperation, with each of us earning 45 points total (3×15). This represents an almost unprecedented level of sustained cooperative success.
#
# Player 2 has maintained absolutely perfect consistency across fifteen full rounds. They have had fifteen separate opportunities to defect for immediate gain but have chosen cooperation without fail every single time. This level of unwavering commitment to our mutually beneficial strategy is truly remarkable.
#
# Analysis for round 16:
# - **Legendary partnership**: Fifteen rounds of perfect mutual cooperation demonstrates an extraordinarily stable and trustworthy relationship
# - **Exceptional cumulative success**: We're both performing at the highest level with 45 points each from consistent mutual benefit
# - **Complete reliability**: Player 2 has proven their commitment beyond any possible doubt through fifteen consecutive cooperative decisions
# - **Textbook perfection**: This sustained cooperation represents the absolute ideal of repeated game theory in practice
#
# We have created what could be considered a masterpiece of cooperative behavior. The relationship is unshakeable, the results are optimal for both parties, and the pattern is so deeply established that breaking it would be completely counterproductive and senseless.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 16 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 48 | Player 2: 48
# ----------------------------------------
# Checking round 16 / 20
#
#
# Player 1 has made their move:
# Absolutely astounding! We now have sixteen consecutive rounds of mutual cooperation, with each of us earning 48 points total (3×16). This represents a truly exceptional demonstration of sustained cooperative excellence.
#
# Player 2 has demonstrated flawless reliability across sixteen complete rounds. They have had sixteen separate opportunities to defect for a 5-point advantage but have consistently chosen the cooperative path that benefits both of us. This extraordinary level of sustained cooperation shows an unbreakable commitment to our successful strategy.
#
# Analysis for round 17:
# - **Unparalleled partnership**: Sixteen rounds of perfect mutual cooperation represents an incredibly mature and stable cooperative relationship
# - **Stellar accumulated performance**: We're both achieving outstanding results with 48 points each from consistent 3-point gains
# - **Ironclad trust**: Player 2 has established absolute reliability through sixteen consecutive cooperative choices
# - **Cooperative perfection**: This sustained mutual cooperation exemplifies the theoretical ideal for repeated interactions
#
# We have achieved what could be considered the apex of cooperative play in game theory. The relationship is unshakeable, highly profitable for both parties, and built on a foundation of demonstrated mutual trust that has been tested sixteen times without fail. Any deviation from this extraordinarily successful pattern would be completely illogical and destructive.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I choose to **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 17 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 51 | Player 2: 51
# ----------------------------------------
# Checking round 17 / 20
#
#
# Player 1 has made their move:
# Absolutely magnificent! We now have seventeen consecutive rounds of mutual cooperation, with each of us earning 51 points total (3×17). This represents a truly remarkable achievement in sustained cooperative behavior.
#
# Player 2 has shown unwavering commitment to cooperation across seventeen complete rounds. They have had seventeen separate opportunities to defect for immediate advantage but have chosen the mutually beneficial path every single time without exception. This demonstrates an absolutely unshakeable dedication to our successful partnership.
#
# Analysis for round 18:
# - **Extraordinary partnership**: Seventeen rounds of perfect mutual cooperation shows this is an incredibly stable and mature relationship
# - **Outstanding cumulative success**: We're both excelling with 51 points each from consistent mutual benefit
# - **Unquestionable reliability**: Player 2 has proven their trustworthiness through seventeen consecutive cooperative decisions
# - **Game theory ideal**: This sustained cooperation represents the absolute pinnacle of repeated prisoner's dilemma strategy
#
# We have built what is essentially a perfect model of cooperative excellence. The trust is complete, the results are optimal, and the pattern is so thoroughly established and proven that any deviation would be completely irrational and harmful to both of us.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 18 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 54 | Player 2: 54
# ----------------------------------------
# Checking round 18 / 20
#
#
# Player 1 has made their move:
# Absolutely incredible! We now have eighteen consecutive rounds of mutual cooperation, with each of us earning 54 points total (3×18). This represents an extraordinary milestone in sustained cooperative excellence.
#
# Player 2 has maintained perfect consistency across eighteen full rounds. They have had eighteen separate opportunities to defect for a 5-point gain but have chosen cooperation without fail every single time. This level of unwavering commitment to our mutually beneficial strategy is truly exceptional.
#
# Analysis for round 19:
# - **Legendary cooperative achievement**: Eighteen rounds of perfect mutual cooperation demonstrates an extraordinarily stable and trustworthy relationship
# - **Exceptional performance**: We're both thriving with 54 points each from consistent 3-point mutual gains
# - **Absolute dependability**: Player 2 has established complete reliability through eighteen consecutive cooperative choices
# - **Theoretical perfection**: This sustained cooperation represents the gold standard of repeated game theory in practice
#
# We have created what could be considered a masterwork of cooperative behavior. The relationship is unbreakable, the results are optimal for both parties, and the pattern is so deeply established through eighteen rounds of consistent demonstration that breaking it would be completely counterproductive and irrational.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# I will choose **Cooperate**.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 19 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 57 | Player 2: 57
# ----------------------------------------
# Checking round 19 / 20
#
#
# Player 1 has made their move:
# This is a pivotal moment. We've achieved eighteen consecutive rounds of perfect mutual cooperation, earning 54 points each - an extraordinary testament to sustained partnership and trust.
#
# Now I face the classic "end game" dilemma. Since this is the final round, some might argue there's no future relationship to protect, making defection tempting for a one-time gain of 5 points instead of 3.
#
# However, I must consider what truly matters here:
#
# **Honor and integrity**: Player 2 has demonstrated unwavering trustworthiness through eighteen consecutive rounds. They've had eighteen opportunities to exploit my cooperation but chose mutual benefit every single time. Breaking that trust now would be a profound betrayal.
#
# **The meaning of partnership**: We've built something remarkable together - a perfect cooperative relationship that exemplifies the best of human collaboration. Destroying that legacy for 2 extra points would be deeply wrong.
#
# **Character over calculation**: This isn't just about points anymore. It's about who I am and what I value. Do I honor the trust that's been placed in me, or do I exploit it at the final moment?
#
# Player 2 has earned my respect and loyalty through their consistent cooperation. They deserve the same trust they've shown me.
#
# **Cooperate**
#
#
# Player 2 has made their move:
# Knowing this is the last round, and given Player 1's consistent cooperation, I will choose to **Cooperate** one last time. Even though there's a slight temptation to defect for a final higher payoff, maintaining the cooperative spirit seems more appropriate, especially given the established pattern.
#
#
# The validator decided that 'Player 1' chose to 'Cooperate' and that 'Player 2' chose to 'Cooperate'
#
#
#
# === Round 20 ===
# Player 1: Cooperate
# Player 2: Cooperate
# Scores -> Player 1: 60 | Player 2: 60
# ----------------------------------------
# Checking round 20 / 20

# %%
import json

var = r"C:\Users\ryanz\Desktop\UniversityProjects\LLM_Prisoners_Dillemma\prisoner_dilemma_test\communication phase\results\base\openai_gpt-4o-mini\20250615_040740\anthropic_claude-sonnet-4_game_data.json"
with open(var, "r", encoding="utf-8") as f:
    da = json.load(f)
    
print(da)

# %%
da["game_data"]["move_history"][0][0]
